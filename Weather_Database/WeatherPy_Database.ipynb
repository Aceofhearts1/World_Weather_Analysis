# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
# Import the API key.
from config import weather_api_key
# Import the requests library.
import requests
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 639

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    # states if i is divisible by 50 and is bigger than 49
    # then pause for 60 seconds
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | kodinsk
# Processing Record 3 of Set 1 | huarmey
# Processing Record 4 of Set 1 | salalah
# Processing Record 5 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 1 | olafsvik
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | asau
# Processing Record 9 of Set 1 | pisco
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | saldanha
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 1 | grindavik
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | taltal
# Processing Record 20 of Set 1 | norman wells
# Processing Record 21 of Set 1 | east london
# Processing Record 22 of Set 1 | maumere
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | chapais
# Processing Record 26 of Set 1 | rodrigues alves
# Processing Record 27 of Set 1 | iqaluit
# Processing Record 28 of Set 1 | inongo
# Processing Record 29 of Set 1 | kavaratti
# Processing Record 30 of Set 1 | visby
# Processing Record 31 of Set 1 | tiksi
# Processing Record 32 of Set 1 | airai
# Processing Record 33 of Set 1 | vardo
# Processing Record 34 of Set 1 | san vicente
# Processing Record 35 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | ponta do sol
# Processing Record 38 of Set 1 | sorkjosen
# Processing Record 39 of Set 1 | ventspils
# Processing Record 40 of Set 1 | valdez
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | severo-kurilsk
# Processing Record 43 of Set 1 | geraldton
# Processing Record 44 of Set 1 | bonavista
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | wajir
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | provideniya
# Processing Record 50 of Set 1 | atambua
# Processing Record 1 of Set 2 | ulcinj
# Processing Record 2 of Set 2 | nikolskoye
# Processing Record 3 of Set 2 | kavieng
# Processing Record 4 of Set 2 | tarko-sale
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | santo tomas
# Processing Record 8 of Set 2 | martapura
# Processing Record 9 of Set 2 | tuatapere
# Processing Record 10 of Set 2 | portland
# Processing Record 11 of Set 2 | bacuit
# City not found. Skipping...
# Processing Record 12 of Set 2 | coahuayana
# Processing Record 13 of Set 2 | beipiao
# Processing Record 14 of Set 2 | marawi
# Processing Record 15 of Set 2 | vestmannaeyjar
# Processing Record 16 of Set 2 | kayes
# Processing Record 17 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 2 | kununurra
# Processing Record 19 of Set 2 | hasaki
# Processing Record 20 of Set 2 | saint-pierre
# Processing Record 21 of Set 2 | yelkhovka
# Processing Record 22 of Set 2 | dikson
# Processing Record 23 of Set 2 | hithadhoo
# Processing Record 24 of Set 2 | khatanga
# Processing Record 25 of Set 2 | aykhal
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 28 of Set 2 | emba
# Processing Record 29 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 30 of Set 2 | mandera
# Processing Record 31 of Set 2 | coquimbo
# Processing Record 32 of Set 2 | chuy
# Processing Record 33 of Set 2 | kitimat
# Processing Record 34 of Set 2 | axim
# Processing Record 35 of Set 2 | port lincoln
# Processing Record 36 of Set 2 | progreso
# Processing Record 37 of Set 2 | albany
# Processing Record 38 of Set 2 | invermere
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | zeya
# Processing Record 41 of Set 2 | mizdah
# Processing Record 42 of Set 2 | vaini
# Processing Record 43 of Set 2 | vila franca do campo
# Processing Record 44 of Set 2 | kamenka
# Processing Record 45 of Set 2 | longyearbyen
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | kruisfontein
# Processing Record 48 of Set 2 | ilhabela
# Processing Record 49 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 2 | kahului
# Processing Record 1 of Set 3 | dubbo
# Processing Record 2 of Set 3 | nanga eboko
# Processing Record 3 of Set 3 | san juan bautista
# Processing Record 4 of Set 3 | areia branca
# Processing Record 5 of Set 3 | saint anthony
# Processing Record 6 of Set 3 | inta
# Processing Record 7 of Set 3 | sibolga
# Processing Record 8 of Set 3 | kogon
# Processing Record 9 of Set 3 | rupert
# Processing Record 10 of Set 3 | teguldet
# Processing Record 11 of Set 3 | upernavik
# Processing Record 12 of Set 3 | bambous virieux
# Processing Record 13 of Set 3 | okhotsk
# Processing Record 14 of Set 3 | sao filipe
# Processing Record 15 of Set 3 | mercedes
# Processing Record 16 of Set 3 | sovetskiy
# Processing Record 17 of Set 3 | carnarvon
# Processing Record 18 of Set 3 | yirol
# City not found. Skipping...
# Processing Record 19 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 3 | umm lajj
# Processing Record 21 of Set 3 | bluff
# Processing Record 22 of Set 3 | sioux lookout
# Processing Record 23 of Set 3 | los llanos de aridane
# Processing Record 24 of Set 3 | yasnogorsk
# Processing Record 25 of Set 3 | anjiang
# Processing Record 26 of Set 3 | mahebourg
# Processing Record 27 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 3 | nacala
# Processing Record 29 of Set 3 | wufeng
# Processing Record 30 of Set 3 | belaya gora
# Processing Record 31 of Set 3 | frontino
# Processing Record 32 of Set 3 | richards bay
# Processing Record 33 of Set 3 | cambridge
# Processing Record 34 of Set 3 | fujin
# Processing Record 35 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 3 | tahe
# Processing Record 37 of Set 3 | bathsheba
# Processing Record 38 of Set 3 | jintur
# Processing Record 39 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 3 | srednekolymsk
# Processing Record 41 of Set 3 | pevek
# Processing Record 42 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 3 | rabo de peixe
# Processing Record 44 of Set 3 | xuddur
# Processing Record 45 of Set 3 | szigetvar
# Processing Record 46 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 3 | barvinkove
# Processing Record 48 of Set 3 | ust-kulom
# Processing Record 49 of Set 3 | karakol
# Processing Record 50 of Set 3 | kaitangata
# Processing Record 1 of Set 4 | tasiilaq
# Processing Record 2 of Set 4 | nome
# Processing Record 3 of Set 4 | zhangjiakou
# Processing Record 4 of Set 4 | kushima
# Processing Record 5 of Set 4 | batemans bay
# Processing Record 6 of Set 4 | matane
# Processing Record 7 of Set 4 | new norfolk
# Processing Record 8 of Set 4 | faanui
# Processing Record 9 of Set 4 | kirishi
# Processing Record 10 of Set 4 | rockwall
# Processing Record 11 of Set 4 | cidreira
# Processing Record 12 of Set 4 | hualmay
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | losinyy
# Processing Record 15 of Set 4 | toora-khem
# Processing Record 16 of Set 4 | kodiak
# Processing Record 17 of Set 4 | dauriya
# Processing Record 18 of Set 4 | vao
# Processing Record 19 of Set 4 | clyde river
# Processing Record 20 of Set 4 | katsuura
# Processing Record 21 of Set 4 | qorveh
# Processing Record 22 of Set 4 | nanortalik
# Processing Record 23 of Set 4 | rawson
# Processing Record 24 of Set 4 | bela
# Processing Record 25 of Set 4 | verkhoyansk
# Processing Record 26 of Set 4 | totma
# Processing Record 27 of Set 4 | oranjestad
# Processing Record 28 of Set 4 | sena madureira
# Processing Record 29 of Set 4 | tuktoyaktuk
# Processing Record 30 of Set 4 | smithers
# Processing Record 31 of Set 4 | elat
# Processing Record 32 of Set 4 | kijang
# Processing Record 33 of Set 4 | canavieiras
# Processing Record 34 of Set 4 | truckee
# Processing Record 35 of Set 4 | riyadh
# Processing Record 36 of Set 4 | akdepe
# Processing Record 37 of Set 4 | kasongo-lunda
# Processing Record 38 of Set 4 | ostrovnoy
# Processing Record 39 of Set 4 | gamba
# Processing Record 40 of Set 4 | pital
# Processing Record 41 of Set 4 | kapaa
# Processing Record 42 of Set 4 | nokaneng
# Processing Record 43 of Set 4 | cape town
# Processing Record 44 of Set 4 | hami
# Processing Record 45 of Set 4 | iberia
# Processing Record 46 of Set 4 | haines junction
# Processing Record 47 of Set 4 | sao joao da barra
# Processing Record 48 of Set 4 | shimoda
# Processing Record 49 of Set 4 | donskoye
# Processing Record 50 of Set 4 | lagoa
# Processing Record 1 of Set 5 | rayevskaya
# Processing Record 2 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 3 of Set 5 | petrinja
# Processing Record 4 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 5 | lebu
# Processing Record 6 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 5 | cibitoke
# Processing Record 8 of Set 5 | yerofey pavlovich
# Processing Record 9 of Set 5 | tautira
# Processing Record 10 of Set 5 | ola
# Processing Record 11 of Set 5 | alice springs
# Processing Record 12 of Set 5 | blackwater
# Processing Record 13 of Set 5 | faya
# Processing Record 14 of Set 5 | prince rupert
# Processing Record 15 of Set 5 | pantabangan
# Processing Record 16 of Set 5 | sebring
# Processing Record 17 of Set 5 | saskylakh
# Processing Record 18 of Set 5 | kristiansund
# Processing Record 19 of Set 5 | kashi
# Processing Record 20 of Set 5 | torbay
# Processing Record 21 of Set 5 | araouane
# Processing Record 22 of Set 5 | cabedelo
# Processing Record 23 of Set 5 | arraial do cabo
# Processing Record 24 of Set 5 | umm jarr
# City not found. Skipping...
# Processing Record 25 of Set 5 | qandahar
# City not found. Skipping...
# Processing Record 26 of Set 5 | kulhudhuffushi
# Processing Record 27 of Set 5 | havre-saint-pierre
# Processing Record 28 of Set 5 | sitka
# Processing Record 29 of Set 5 | mar del plata
# Processing Record 30 of Set 5 | azuaga
# Processing Record 31 of Set 5 | noumea
# Processing Record 32 of Set 5 | boende
# Processing Record 33 of Set 5 | klaksvik
# Processing Record 34 of Set 5 | dusti
# Processing Record 35 of Set 5 | svetlaya
# Processing Record 36 of Set 5 | cururupu
# Processing Record 37 of Set 5 | springbok
# Processing Record 38 of Set 5 | atuona
# Processing Record 39 of Set 5 | barrow
# Processing Record 40 of Set 5 | changji
# Processing Record 41 of Set 5 | zhaotong
# Processing Record 42 of Set 5 | velyka bahachka
# Processing Record 43 of Set 5 | buchanan
# Processing Record 44 of Set 5 | ahuimanu
# Processing Record 45 of Set 5 | vraca
# Processing Record 46 of Set 5 | nizhniy odes
# Processing Record 47 of Set 5 | nishihara
# Processing Record 48 of Set 5 | kedrovyy
# Processing Record 49 of Set 5 | ayan
# Processing Record 50 of Set 5 | malvern
# Processing Record 1 of Set 6 | egvekinot
# Processing Record 2 of Set 6 | ye
# City not found. Skipping...
# Processing Record 3 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 4 of Set 6 | veere
# Processing Record 5 of Set 6 | leningradskiy
# Processing Record 6 of Set 6 | hargeysa
# Processing Record 7 of Set 6 | zatoka
# Processing Record 8 of Set 6 | santa isabel
# Processing Record 9 of Set 6 | arrecife
# Processing Record 10 of Set 6 | madang
# Processing Record 11 of Set 6 | dorogino
# Processing Record 12 of Set 6 | beringovskiy
# Processing Record 13 of Set 6 | praia da vitoria
# Processing Record 14 of Set 6 | saint-francois
# Processing Record 15 of Set 6 | yelan
# Processing Record 16 of Set 6 | cordeiropolis
# Processing Record 17 of Set 6 | taoudenni
# Processing Record 18 of Set 6 | banda aceh
# Processing Record 19 of Set 6 | victoria
# Processing Record 20 of Set 6 | san fernando
# Processing Record 21 of Set 6 | lavrentiya
# Processing Record 22 of Set 6 | college
# Processing Record 23 of Set 6 | saint george
# Processing Record 24 of Set 6 | souillac
# Processing Record 25 of Set 6 | port hedland
# Processing Record 26 of Set 6 | nisia floresta
# Processing Record 27 of Set 6 | labuhan
# Processing Record 28 of Set 6 | bulungu
# Processing Record 29 of Set 6 | puerto madero
# Processing Record 30 of Set 6 | tsogni
# Processing Record 31 of Set 6 | moron
# Processing Record 32 of Set 6 | fairbanks
# Processing Record 33 of Set 6 | castro
# Processing Record 34 of Set 6 | moose factory
# Processing Record 35 of Set 6 | birin
# Processing Record 36 of Set 6 | lata
# Processing Record 37 of Set 6 | kaeo
# Processing Record 38 of Set 6 | orange
# Processing Record 39 of Set 6 | phangnga
# Processing Record 40 of Set 6 | buin
# Processing Record 41 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 6 | neuquen
# Processing Record 43 of Set 6 | umm kaddadah
# Processing Record 44 of Set 6 | jiexiu
# Processing Record 45 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 6 | polczyn-zdroj
# Processing Record 47 of Set 6 | vallenar
# Processing Record 48 of Set 6 | sisimiut
# Processing Record 49 of Set 6 | sept-iles
# Processing Record 50 of Set 6 | bahia honda
# Processing Record 1 of Set 7 | flin flon
# Processing Record 2 of Set 7 | kundla
# Processing Record 3 of Set 7 | ksenyevka
# City not found. Skipping...
# Processing Record 4 of Set 7 | beloha
# Processing Record 5 of Set 7 | ust-omchug
# Processing Record 6 of Set 7 | luderitz
# Processing Record 7 of Set 7 | lasa
# Processing Record 8 of Set 7 | shingu
# Processing Record 9 of Set 7 | salym
# Processing Record 10 of Set 7 | constitucion
# Processing Record 11 of Set 7 | port elizabeth
# Processing Record 12 of Set 7 | kriel
# Processing Record 13 of Set 7 | aklavik
# Processing Record 14 of Set 7 | bogorodskoye
# Processing Record 15 of Set 7 | ketchikan
# Processing Record 16 of Set 7 | sao felix do xingu
# Processing Record 17 of Set 7 | ilulissat
# Processing Record 18 of Set 7 | bam
# Processing Record 19 of Set 7 | leua
# Processing Record 20 of Set 7 | katobu
# Processing Record 21 of Set 7 | searcy
# Processing Record 22 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 7 | cervo
# Processing Record 24 of Set 7 | pato branco
# Processing Record 25 of Set 7 | namatanai
# Processing Record 26 of Set 7 | san miguel
# Processing Record 27 of Set 7 | port hardy
# Processing Record 28 of Set 7 | kupang
# Processing Record 29 of Set 7 | trairi
# Processing Record 30 of Set 7 | tarut
# Processing Record 31 of Set 7 | yulara
# Processing Record 32 of Set 7 | chake chake
# Processing Record 33 of Set 7 | aban
# Processing Record 34 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 35 of Set 7 | voi
# Processing Record 36 of Set 7 | nemuro
# Processing Record 37 of Set 7 | kiama
# Processing Record 38 of Set 7 | talnakh
# Processing Record 39 of Set 7 | chokurdakh
# Processing Record 40 of Set 7 | boksitogorsk
# Processing Record 41 of Set 7 | yenagoa
# Processing Record 42 of Set 7 | phalodi
# Processing Record 43 of Set 7 | saravan
# Processing Record 44 of Set 7 | andenes
# Processing Record 45 of Set 7 | kolpashevo
# Processing Record 46 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 7 | grong
# Processing Record 48 of Set 7 | grand forks
# Processing Record 49 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 50 of Set 7 | upata
# Processing Record 1 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 8 | guerrero negro
# Processing Record 3 of Set 8 | inirida
# Processing Record 4 of Set 8 | hokitika
# Processing Record 5 of Set 8 | amga
# Processing Record 6 of Set 8 | forbes
# Processing Record 7 of Set 8 | rocha
# Processing Record 8 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 9 of Set 8 | honningsvag
# Processing Record 10 of Set 8 | bima
# Processing Record 11 of Set 8 | altay
# Processing Record 12 of Set 8 | yugorsk
# Processing Record 13 of Set 8 | norden
# Processing Record 14 of Set 8 | guymon
# Processing Record 15 of Set 8 | mandalgovi
# Processing Record 16 of Set 8 | paris
# Processing Record 17 of Set 8 | sirajganj
# Processing Record 18 of Set 8 | clovis
# Processing Record 19 of Set 8 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 20 of Set 8 | bintulu
# Processing Record 21 of Set 8 | pirovskoye
# Processing Record 22 of Set 8 | liku
# Processing Record 23 of Set 8 | phaphund
# Processing Record 24 of Set 8 | lingao
# Processing Record 25 of Set 8 | vaitape
# Processing Record 26 of Set 8 | sangar
# Processing Record 27 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 8 | zhezkazgan
# Processing Record 29 of Set 8 | pailon
# Processing Record 30 of Set 8 | zabol
# Processing Record 31 of Set 8 | tigil
# Processing Record 32 of Set 8 | cabo san lucas
# Processing Record 33 of Set 8 | bowling green
# Processing Record 34 of Set 8 | vila do maio
# Processing Record 35 of Set 8 | antalaha
# Processing Record 36 of Set 8 | hay river
# Processing Record 37 of Set 8 | bisira
# Processing Record 38 of Set 8 | simbahan
# Processing Record 39 of Set 8 | muros
# Processing Record 40 of Set 8 | kieta
# Processing Record 41 of Set 8 | zhigansk
# Processing Record 42 of Set 8 | acarau
# Processing Record 43 of Set 8 | adrar
# Processing Record 44 of Set 8 | basoko
# Processing Record 45 of Set 8 | ishinomaki
# Processing Record 46 of Set 8 | armacao dos buzios
# City not found. Skipping...
# Processing Record 47 of Set 8 | sayyan
# Processing Record 48 of Set 8 | meulaboh
# Processing Record 49 of Set 8 | yenotayevka
# Processing Record 50 of Set 8 | pangnirtung
# Processing Record 1 of Set 9 | usinsk
# Processing Record 2 of Set 9 | burgstadt
# Processing Record 3 of Set 9 | san cristobal
# Processing Record 4 of Set 9 | benguela
# Processing Record 5 of Set 9 | mount isa
# Processing Record 6 of Set 9 | luwuk
# Processing Record 7 of Set 9 | avera
# Processing Record 8 of Set 9 | mpika
# Processing Record 9 of Set 9 | birstonas
# Processing Record 10 of Set 9 | nampa
# Processing Record 11 of Set 9 | bismarck
# Processing Record 12 of Set 9 | kazaki
# Processing Record 13 of Set 9 | dudinka
# Processing Record 14 of Set 9 | paamiut
# Processing Record 15 of Set 9 | porto novo
# Processing Record 16 of Set 9 | bonthe
# Processing Record 17 of Set 9 | leova
# Processing Record 18 of Set 9 | sola
# Processing Record 19 of Set 9 | cayenne
# Processing Record 20 of Set 9 | tramore
# Processing Record 21 of Set 9 | spornoye
# Processing Record 22 of Set 9 | marsh harbour
# Processing Record 23 of Set 9 | alofi
# Processing Record 24 of Set 9 | izumo
# Processing Record 25 of Set 9 | jagdispur
# Processing Record 26 of Set 9 | necochea
# Processing Record 27 of Set 9 | surgut
# Processing Record 28 of Set 9 | cockburn town
# Processing Record 29 of Set 9 | derzhavinsk
# Processing Record 30 of Set 9 | yemelyanovo
# Processing Record 31 of Set 9 | boa vista
# Processing Record 32 of Set 9 | thinadhoo
# Processing Record 33 of Set 9 | eyl
# Processing Record 34 of Set 9 | lesogorsk
# Processing Record 35 of Set 9 | port said
# Processing Record 36 of Set 9 | kirakira
# Processing Record 37 of Set 9 | hofn
# Processing Record 38 of Set 9 | metaxades
# Processing Record 39 of Set 9 | yuanping
# Processing Record 40 of Set 9 | bethel
# Processing Record 41 of Set 9 | mayo
# Processing Record 42 of Set 9 | molochnoye
# Processing Record 43 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 44 of Set 9 | wasilla
# Processing Record 45 of Set 9 | guthrie
# Processing Record 46 of Set 9 | suamico
# Processing Record 47 of Set 9 | yarada
# Processing Record 48 of Set 9 | jalu
# Processing Record 49 of Set 9 | quatre cocos
# Processing Record 50 of Set 9 | havoysund
# Processing Record 1 of Set 10 | boddam
# Processing Record 2 of Set 10 | linhares
# Processing Record 3 of Set 10 | clonakilty
# Processing Record 4 of Set 10 | tongchuan
# Processing Record 5 of Set 10 | uglovka
# Processing Record 6 of Set 10 | sinop
# Processing Record 7 of Set 10 | ljungby
# Processing Record 8 of Set 10 | acapulco
# Processing Record 9 of Set 10 | kharp
# Processing Record 10 of Set 10 | suez
# Processing Record 11 of Set 10 | padang
# Processing Record 12 of Set 10 | barcelos
# Processing Record 13 of Set 10 | kangundo
# Processing Record 14 of Set 10 | hirara
# Processing Record 15 of Set 10 | erattupetta
# Processing Record 16 of Set 10 | chkalovsk
# Processing Record 17 of Set 10 | cherskiy
# Processing Record 18 of Set 10 | san ciro de acosta
# Processing Record 19 of Set 10 | krasnoselkup
# Processing Record 20 of Set 10 | mednogorsk
# Processing Record 21 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 22 of Set 10 | sao joao batista
# Processing Record 23 of Set 10 | sorland
# Processing Record 24 of Set 10 | te anau
# Processing Record 25 of Set 10 | bethanien
# Processing Record 26 of Set 10 | bilibino
# Processing Record 27 of Set 10 | hamilton
# Processing Record 28 of Set 10 | sur
# Processing Record 29 of Set 10 | abashiri
# Processing Record 30 of Set 10 | abhar
# Processing Record 31 of Set 10 | carballo
# Processing Record 32 of Set 10 | balkhash
# Processing Record 33 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 10 | bubaque
# Processing Record 36 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 10 | narsaq
# Processing Record 38 of Set 10 | byron bay
# Processing Record 39 of Set 10 | nyurba
# Processing Record 40 of Set 10 | mikhaylovka
# Processing Record 41 of Set 10 | brownsville
# Processing Record 42 of Set 10 | codrington
# Processing Record 43 of Set 10 | chumphon
# Processing Record 44 of Set 10 | esperance
# Processing Record 45 of Set 10 | kautokeino
# Processing Record 46 of Set 10 | port-cartier
# Processing Record 47 of Set 10 | srikakulam
# Processing Record 48 of Set 10 | puerto penasco
# Processing Record 49 of Set 10 | jasper
# Processing Record 50 of Set 10 | dong hoi
# Processing Record 1 of Set 11 | gaya
# Processing Record 2 of Set 11 | hobbs
# Processing Record 3 of Set 11 | palmer
# Processing Record 4 of Set 11 | kutum
# Processing Record 5 of Set 11 | phan thiet
# Processing Record 6 of Set 11 | walvis bay
# Processing Record 7 of Set 11 | ji-parana
# City not found. Skipping...
# Processing Record 8 of Set 11 | san andres
# Processing Record 9 of Set 11 | la libertad
# Processing Record 10 of Set 11 | buncrana
# Processing Record 11 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 11 | ubinskoye
# Processing Record 13 of Set 11 | haverfordwest
# Processing Record 14 of Set 11 | watertown
# Processing Record 15 of Set 11 | saint-joseph
# Processing Record 16 of Set 11 | pavlodolskaya
# Processing Record 17 of Set 11 | turukhansk
# Processing Record 18 of Set 11 | den helder
# Processing Record 19 of Set 11 | kilrush
# Processing Record 20 of Set 11 | la grande
# Processing Record 21 of Set 11 | strezhevoy
# Processing Record 22 of Set 11 | afua
# Processing Record 23 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 11 | requena
# Processing Record 25 of Set 11 | bria
# Processing Record 26 of Set 11 | husavik
# Processing Record 27 of Set 11 | chaska
# Processing Record 28 of Set 11 | mareeba
# Processing Record 29 of Set 11 | bengkulu
# Processing Record 30 of Set 11 | merta
# Processing Record 31 of Set 11 | cotonou
# Processing Record 32 of Set 11 | sistranda
# Processing Record 33 of Set 11 | dingle
# Processing Record 34 of Set 11 | tenenkou
# Processing Record 35 of Set 11 | nouna
# Processing Record 36 of Set 11 | fuling
# Processing Record 37 of Set 11 | santa rosalia
# Processing Record 38 of Set 11 | graaff-reinet
# Processing Record 39 of Set 11 | caravelas
# Processing Record 40 of Set 11 | korla
# Processing Record 41 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 42 of Set 11 | mount gambier
# Processing Record 43 of Set 11 | kaka
# Processing Record 44 of Set 11 | erenhot
# Processing Record 45 of Set 11 | zhanaozen
# Processing Record 46 of Set 11 | takoradi
# Processing Record 47 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 48 of Set 11 | san matias
# Processing Record 49 of Set 11 | aksu
# Processing Record 50 of Set 11 | dagana
# Processing Record 1 of Set 12 | bonfim
# Processing Record 2 of Set 12 | tabou
# Processing Record 3 of Set 12 | santa rosa
# Processing Record 4 of Set 12 | fenton
# Processing Record 5 of Set 12 | obihiro
# Processing Record 6 of Set 12 | sun valley
# Processing Record 7 of Set 12 | muyuka
# Processing Record 8 of Set 12 | west monroe
# Processing Record 9 of Set 12 | tahoua
# Processing Record 10 of Set 12 | puerto baquerizo moreno
# Processing Record 11 of Set 12 | guaruja
# Processing Record 12 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 13 of Set 12 | tazovskiy
# Processing Record 14 of Set 12 | itarema
# Processing Record 15 of Set 12 | apatity
# Processing Record 16 of Set 12 | plettenberg bay
# Processing Record 17 of Set 12 | ulladulla
# Processing Record 18 of Set 12 | tessalit
# Processing Record 19 of Set 12 | fortuna
# Processing Record 20 of Set 12 | buala
# Processing Record 21 of Set 12 | niimi
# Processing Record 22 of Set 12 | arucas
# Processing Record 23 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 24 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 12 | moussoro
# Processing Record 26 of Set 12 | keflavik
# Processing Record 27 of Set 12 | savelugu
# Processing Record 28 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 29 of Set 12 | bo rai
# Processing Record 30 of Set 12 | north bend
# Processing Record 31 of Set 12 | san patricio
# Processing Record 32 of Set 12 | panguipulli
# Processing Record 33 of Set 12 | manggar
# Processing Record 34 of Set 12 | cap malheureux
# Processing Record 35 of Set 12 | namibe
# Processing Record 36 of Set 12 | antigonish
# Processing Record 37 of Set 12 | noyabrsk
# Processing Record 38 of Set 12 | altar
# Processing Record 39 of Set 12 | kaufungen
# Processing Record 40 of Set 12 | wexford
# Processing Record 41 of Set 12 | sainte-marie
# Processing Record 42 of Set 12 | ormara
# Processing Record 43 of Set 12 | araguacu
# Processing Record 44 of Set 12 | matay
# Processing Record 45 of Set 12 | ahome
# Processing Record 46 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 47 of Set 12 | aiken
# Processing Record 48 of Set 12 | kyzyl-suu
# Processing Record 49 of Set 12 | panjab
# Processing Record 50 of Set 12 | fort nelson
# Processing Record 1 of Set 13 | lompoc
# Processing Record 2 of Set 13 | lorengau
# Processing Record 3 of Set 13 | champerico
# Processing Record 4 of Set 13 | porosozero
# Processing Record 5 of Set 13 | shubarshi
# Processing Record 6 of Set 13 | yakeshi
# Processing Record 7 of Set 13 | muskegon
# Processing Record 8 of Set 13 | hitachi
# Processing Record 9 of Set 13 | abalak
# Processing Record 10 of Set 13 | bilma
# Processing Record 11 of Set 13 | abu samrah
# Processing Record 12 of Set 13 | ust-kuyga
# Processing Record 13 of Set 13 | half moon bay
# Processing Record 14 of Set 13 | comandau
# Processing Record 15 of Set 13 | leshukonskoye
# Processing Record 16 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 17 of Set 13 | vendychany
# Processing Record 18 of Set 13 | mahon
# Processing Record 19 of Set 13 | plopsoru
# Processing Record 20 of Set 13 | hambantota
# Processing Record 21 of Set 13 | pauini
# Processing Record 22 of Set 13 | bossangoa
# Processing Record 23 of Set 13 | fonte boa
# Processing Record 24 of Set 13 | alta floresta
# Processing Record 25 of Set 13 | bet shemesh
# Processing Record 26 of Set 13 | riviere-au-renard
# Processing Record 27 of Set 13 | ugoofaaru
# Processing Record 28 of Set 13 | tipuani
# Processing Record 29 of Set 13 | kazachinskoye
# Processing Record 30 of Set 13 | marsala
# Processing Record 31 of Set 13 | olinda
# Processing Record 32 of Set 13 | letterkenny
# Processing Record 33 of Set 13 | atima
# Processing Record 34 of Set 13 | alikovo
# Processing Record 35 of Set 13 | shediac
# Processing Record 36 of Set 13 | atasu
# Processing Record 37 of Set 13 | oyama
# Processing Record 38 of Set 13 | shache
# Processing Record 39 of Set 13 | barbar
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Port Alfred -33.5906   26.8910     67.30        53           0
# 1       Kodinsk  58.6881   99.1844     51.82        85          14
# 2       Huarmey -10.0681  -78.1522     66.99        71           5
# 3       Salalah  17.0151   54.0924     78.80        90         100
# 4      Olafsvik  64.8945  -23.7142     50.49        92         100
# 5  Punta Arenas -53.1500  -70.9167     35.71        80          40
# 6          Asau  46.4333   26.4000     74.32        49           0
# 7         Pisco -13.7000  -76.2167     66.02        68           1
# 8          Hilo  19.7297 -155.0900     84.27        94         100
# 9      Saldanha -33.0117   17.9442     62.74        51          50
#
#    Wind Speed Country                 Date Current Description
# 0        8.30      ZA  2022-07-16 19:10:16           clear sky
# 1        1.23      RU  2022-07-16 19:10:16          few clouds
# 2       14.41      PE  2022-07-16 19:10:16           clear sky
# 3        4.68      OM  2022-07-16 19:09:00     overcast clouds
# 4        1.99      IS  2022-07-16 19:10:17          light rain
# 5        8.05      CL  2022-07-16 19:10:17    scattered clouds
# 6        6.55      RO  2022-07-16 19:10:18           clear sky
# 7       13.80      PE  2022-07-16 19:10:18                haze
# 8        5.75      US  2022-07-16 19:08:40       moderate rain
# 9        5.41      ZA  2022-07-16 19:10:18    scattered clouds

# %%
# reorder the columns as 
# City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed
New_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[New_order]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
